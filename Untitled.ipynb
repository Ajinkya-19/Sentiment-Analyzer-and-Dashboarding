# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\hp\Documents\Udemy course\Data Scientist project\Classification\sentiment analysis\amazon_alexa.tsv",delimiter='\t')

# %%
df.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rating            3150 non-null   int64
#  1   date              3150 non-null   object
#  2   variation         3150 non-null   object
#  3   verified_reviews  3149 non-null   object
#  4   feedback          3150 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 123.2+ KB

# %%
df.describe()
# Out:
#             rating     feedback
# count  3150.000000  3150.000000
# mean      4.463175     0.918413
# std       1.068506     0.273778
# min       1.000000     0.000000
# 25%       4.000000     1.000000
# 50%       5.000000     1.000000
# 75%       5.000000     1.000000
# max       5.000000     1.000000

# %%
df.shape
# Out:
# (3150, 5)

# %%
# Check for missing values to handle it if exist
df.isnull().sum()
# Out:
# rating              0
# date                0
# variation           0
# verified_reviews    1
# feedback            0
# dtype: int64

# %%
df[df['verified_reviews'].isna()]
# Out:
#      rating       date variation verified_reviews  feedback
# 473       2  29-Jun-18     White              NaN         0

# %%
df = df.dropna()

# %%
df.head(2)
# Out:
#    rating       date         variation verified_reviews  feedback
# 0       5  31-Jul-18  Charcoal Fabric     Love my Echo!         1
# 1       5  31-Jul-18  Charcoal Fabric         Loved it!         1

# %%
pd.to_datetime(df['date'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_964\251164130.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df['date'])
# 0      2018-07-31
# 1      2018-07-31
# 2      2018-07-31
# 3      2018-07-31
# 4      2018-07-31
#           ...
# 3145   2018-07-30
# 3146   2018-07-30
# 3147   2018-07-30
# 3148   2018-07-30
# 3149   2018-07-29
# Name: date, Length: 3149, dtype: datetime64[ns]

# %%
# Check for missing values to handle it if exist
df.isnull().sum()
# Out:
# rating              0
# date                0
# variation           0
# verified_reviews    0
# feedback            0
# dtype: int64

# %%
# Show columns names and its types
df.dtypes
# Out:
# rating               int64
# date                object
# variation           object
# verified_reviews    object
# feedback             int64
# dtype: object

# %%
# Explore rating column
rating_counts = df['rating'].value_counts()
print(rating_counts)
# Out:
# rating
# 5    2286
# 4     455
# 1     161
# 3     152
# 2      95
# Name: count, dtype: int64

# %%
df['feedback'] = df['rating'].apply(lambda x: 1 if x in [4, 5] else 0)

# %%
plt.bar(rating_counts.index, rating_counts)
plt.show()

# %%
# Explore feedback column to check about unbalanced
feedback_counts = df['feedback'].value_counts()
plt.pie(feedback_counts, labels = feedback_counts.index, explode = [0.1,0.1], shadow = True, autopct = '%1.1f%%')
plt.show()

# %%
neg_review = df[df['feedback'] == 0]

# %%
pos_review =  df[df['feedback'] == 1]

# %%
df[df['feedback'] == 0]['rating'].value_counts()# rating in negative feedback
# Out:
# rating
# 1    161
# 3    152
# 2     95
# Name: count, dtype: int64

# %%
ratings_neg = df[df['feedback'] == 0]['rating'].value_counts()
print("ratings of negative feedbacks\n",ratings_neg, '\n')
# Out:
# ratings of negative feedbacks
#  rating
# 1    161
# 3    152
# 2     95
# Name: count, dtype: int64

# %%
ratings_pos = df[df['feedback'] == 1]['rating'].value_counts()
print("ratings of positive feedbacks\n",ratings_pos, '\n')
# Out:
# ratings of positive feedbacks
#  rating
# 5    2286
# 4     455
# Name: count, dtype: int64

# %%
# Explore variation column
variation_counts = df['variation'].value_counts()
print(variation_counts)
# Out:
# variation
# Black  Dot                      516
# Charcoal Fabric                 430
# Configuration: Fire TV Stick    350
# Black  Plus                     270
# Black  Show                     265
# Black                           261
# Black  Spot                     241
# White  Dot                      184
# Heather Gray Fabric             157
# White  Spot                     109
# Sandstone Fabric                 90
# White                            90
# White  Show                      85
# White  Plus                      78
# Oak Finish                       14
# Walnut Finish                     9
# Name: count, dtype: int64

# %%
plt.barh(variation_counts.index, variation_counts, color = 'red')
plt.show()

# %%
# Show mean rating according to variation column
average_ratings = df.groupby('variation')['rating'].mean().sort_values(ascending = False)
plt.barh(average_ratings.index, average_ratings, color = 'green')
plt.show()

# %%
df.to_csv('alexa.csv')

# %%
# Create legnth variable to store the lengh of each review
lengths = df['verified_reviews'].apply(len)

# %%
print(df['verified_reviews'][:1])
print(lengths[0])
# Out:
# 0    Love my Echo!
# Name: verified_reviews, dtype: object
# 13

# %%
plt.hist(lengths)
plt.xlabel('length')
plt.ylabel('counts')
plt.show()

# %%
df.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %% [markdown]
# ### 3. Data Preprocessing

# %% [markdown]
# * Lower case
# * Tokenization
# * Removing special characters
# * Removing stop words and punctuation
# * Stemming

# %%
import nltk
nltk.download('punkt')  # Punctuation

import string
string.punctuation

import nltk
from nltk.corpus import stopwords #Stopwords

from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()  # Stemming
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
# Data Preprocessing Function
def transform_text(text):
    text = text.lower()           # Lowercase
    text = nltk.word_tokenize(text)# Tokenization
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:  # Stopword ans Punctuation Remover
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))  # Stemming
    
            
    return " ".join(y)

# %%
#Test the Function
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
sia.polarity_scores('gon na home soon want talk stuff anymor tonight k cri enough today')
# Out:
# {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.0772}

# %%
df['verified_reviews'][10]
# Out:
# 'I sent it to my 85 year old Dad, and he talks to it constantly.'

# %%
transform_text(df['verified_reviews'][10])
# Out:
# 'sent 85 year old dad talk constantli'

# %%
df.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
df[df['rating']==2]
# Out:
#       rating       date             variation  \
# 46         2  30-Jul-18      Charcoal Fabric
# 111        2  30-Jul-18      Charcoal Fabric
# 176        2  30-Jul-18  Heather Gray Fabric
# 187        2  29-Jul-18      Charcoal Fabric
# 205        2  29-Jul-18     Sandstone Fabric
# ...      ...        ...                   ...
# 2945       2  30-Jul-18            Black  Dot
# 2964       2  30-Jul-18            Black  Dot
# 3010       2  30-Jul-18            Black  Dot
# 3039       2  30-Jul-18            Black  Dot
# 3067       2  30-Jul-18            Black  Dot
#
#                                        verified_reviews  feedback
# 46    It's like Siri, in fact, Siri answers more acc...         0
# 111   Sound is terrible if u want good music too get...         0
# 176                                Sad joke. Worthless.         0
# 187   Really disappointed Alexa has to be plug-in to...         0
# 205   It's got great sound and bass but it doesn't w...         0
# ...                                                 ...       ...
# 2945  When you think about it this really doesn’t do...         0
# 2964  Ask it to play Motown radio on Pandora and it ...         0
# 3010  Sound is terrible. Cannot pair with echo to pl...         0
# 3039  Weak sound. Compared to the Google Home Mini t...         0
# 3067  The only negative we have on this product is t...         0
#
# [95 rows x 5 columns]

# %%
df['trans_reviews'] = df['verified_reviews'].apply(transform_text)

# %%
df.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback  \
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1
#
#                                        trans_reviews
# 0                                          love echo
# 1                                               love
# 2  sometim play game answer question correctli al...
# 3  lot fun thing 4 yr old learn dinosaur control ...
# 4                                              music

# %%
df['feedback'].value_counts()   #256*10
# Out:
# feedback
# 1    2741
# 0     408
# Name: count, dtype: int64

# %%
256*11
# Out:
# 2816

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
df[df['feedback']==1]['trans_reviews'].str.cat(sep=" ")  #  feedback 1 is in string
# Out:
# 'love echo love sometim play game answer question correctli alexa say got wrong answer like abl turn light away home lot fun thing 4 yr old learn dinosaur control light play game like categori nice sound play music well music receiv echo gift need anoth bluetooth someth play music easili access found smart speaker wait see els think 5th one purchas work get one everi room hous realli like featur offer specifili play music echo control light throughout hous look great love listen song heard sinc childhood get news weather inform great sent 85 year old dad talk constantli love learn knew thing eveyday still figur everyth work far easi use understand make laugh time purchas mother knee problem give someth tri come get around fast like enjoy littl big thing alexa play song time cook love love love expect love wife hate realli happi purchas great speaker easi set use alexa coupl day lot fun new toy like new household member tri learn differ featu benefit come love size 2nd gener echo still need littl improv sound like origin echo shorter greater choic miss volum ring top button big deal ring w comfort well like use standard usb charger instead previou round pin guess sound seem work still answer like love echo good music sound play alexa understand command difficult time find specif playlist song spotifi good amazon music lack major program love alexa use play music play radio itun play podcast anypod set remind listen flash brief news weather everi morn reli custom list like abl voic control volum sure continu find new bit frustrat alexa understand say set day still ad smart home devic speaker great play music like size station kitchen counter intrus look love play sleep sound immedi ask amaz product love echo easi oper load everyth advertis use mainli play favorit tune test alexa knowledg sound great love fun item play get use use sometim hard time answer question ask think better like one still learn capabl far pretti pretti pretti good like work well need learn command uniqu owner user like alexa learn tasha birthday alexa learn definit fine etc great devic awesom bought compar speaker qualiti first gener speaker like sound better ship daughter though like fact first gener chargeabl base bought keep mobil need better sound love echo still learn thing abl follow instruct includ packag found great one speaker better 1st gener echo thing way cool get one want cool first digit assist give good review speaker realli good cheap price prime day fun play use alarm clock go get first place end echo go one definit tri like best number devic connect purchas came smart plug 10 connect lamp alexa turn light husband like abl use listen music wish knew capabl android would allow alexa connect fortun sister appl cell tech support fix glitch run far good tri play certain broadway show like camelot give ne group camelot great satisfi echo alexa control light famili room wife listen jimmi buffet ask alexa love echo still learn everi thing work ton fun love much excelent lo unico es que esta en español still learn use far echo great sound actual much better expect work expect also good sound qualiti consid price sale featur sound echo 2nd gener phenomen mention love alexa help let play learn get work advertis easi setup still learn great sound easi set love alexa bought other friend love echo purchas compani husband 83 alexa great say name tell joke play favorit song  love abl listen music easili still learn featur avail realli know could use devic use thing need overview love wish built hub use primarili play music work wonder still get use mani thing amazon sent sever tip sinc got thank help easi set fast respons amaz clear concis answer sound qualiti fantast still get use alexia usd echo full extent need na na nana everyth expect love echo work like said would 34 smart 34 home speak function everyth els good great sound small set use fun work sound great sound amaz mani collect music set alway listen awesom bought control fio televis work well  ...

# %%
happy_wc = wc.generate(df[df['feedback']==1]['trans_reviews'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(happy_wc)

# %%
unhappy_wc = wc.generate(df[df['feedback']==0]['trans_reviews'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(unhappy_wc)

# %%
from collections import Counter

# %%
happy_corpus = []
for msg in df[df['feedback'] == 1]['trans_reviews'].tolist():
    for word in msg.split():
        happy_corpus.append(word)

# %%
len(happy_corpus)
# Out:
# 31375

# %%
Counter(happy_corpus).most_common(30)
# Out:
# [('love', 1042),
#  ('echo', 711),
#  ('great', 688),
#  ('use', 627),
#  ('alexa', 519),
#  ('work', 510),
#  ('music', 477),
#  ('like', 452),
#  ('sound', 354),
#  ('easi', 330),
#  ('one', 308),
#  ('set', 306),
#  ('play', 280),
#  ('get', 277),
#  ('dot', 268),
#  ('good', 239),
#  ('devic', 239),
#  ('speaker', 236),
#  ('product', 222),
#  ('thing', 221),
#  ('home', 193),
#  ('time', 183),
#  ('still', 174),
#  ('amazon', 173),
#  ('smart', 167),
#  ('learn', 165),
#  ('show', 164),
#  ('new', 162),
#  ('light', 161),
#  ('purchas', 156)]

# %%
unhappy_corpus = []
for msg in df[df['feedback'] == 0]['trans_reviews'].tolist():
    for word in msg.split():
        unhappy_corpus.append(word)

# %%
len(unhappy_corpus)
# Out:
# 7916

# %%
Counter(unhappy_corpus).most_common(30)
# Out:
# [('echo', 146),
#  ('work', 138),
#  ('alexa', 107),
#  ('devic', 106),
#  ('use', 87),
#  ('amazon', 82),
#  ('like', 80),
#  ('34', 78),
#  ('get', 77),
#  ('would', 77),
#  ('dot', 75),
#  ('time', 73),
#  ('sound', 71),
#  ('speaker', 69),
#  ('music', 60),
#  ('one', 57),
#  ('product', 55),
#  ('tri', 53),
#  ('play', 52),
#  ('thing', 52),
#  ('set', 48),
#  ('need', 47),
#  ('ask', 44),
#  ('want', 44),
#  ('buy', 44),
#  ('connect', 43),
#  ('screen', 43),
#  ('better', 41),
#  ('also', 41),
#  ('qualiti', 40)]

# %%
! pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\hp\anaconda3\lib\site-packages (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
RandomOverSampler = RandomOverSampler(sampling_strategy = 1)

# %% [markdown]
# ### Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
#cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['trans_reviews']).toarray()

# %%
y=df['feedback'].values

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
X.shape
# Out:
# (3149, 2774)

# %%
y.shape
# Out:
# (3149,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
RandomOverSampler = RandomOverSampler(sampling_strategy = 1)

# %%
X_train_resampled, y_train_resampled = RandomOverSampler.fit_resample(X_train,y_train)

# %%
y_train_resampled.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 y_train_resampled.value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,classification_report, recall_score, f1_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train_resampled, y_train_resampled)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.5132275132275133
# [[ 96  45]
#  [415 389]]
# 0.8963133640552995

# %%
mnb.fit(X_train_resampled, y_train_resampled)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.8645502645502645
# [[114  27]
#  [101 703]]
# 0.963013698630137

# %%
bnb.fit(X_train_resampled, y_train_resampled)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.8677248677248677
# [[ 62  79]
#  [ 46 758]]
# 0.9056152927120669

# %%
# bc = BaggingClassifier(n_estimators=50, random_state=2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', class_weight = {0:11,1:1},gamma=1.0)
#knc = KNeighborsClassifier()
#mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5,class_weight = {0:11,1:1})
lrc = LogisticRegression(solver='liblinear', class_weight={0:11,1:1} ,penalty='l1')
rfc = RandomForestClassifier(n_estimators=50,class_weight = {0:11,1:1}, random_state=2)
#abc = AdaBoostClassifier(n_estimators=50,random_state=2)
#bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2,class_weight = {0:11,1:1})
#gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2,class_weight = {0:11,1:1})

# %%
clfs = {
    'SVC' : svc,
    #'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    #'AdaBoost': abc, 
    #'BgC': bc, 
    'ETC': etc,
    #'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train_resampled, y_train_resampled,X_test,y_test):
    clf.fit(X_train_resampled, y_train_resampled)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train_resampled, y_train_resampled,X_test,y_test)
# Out:
# (0.744973544973545, 0.9562398703403565)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train_resampled, y_train_resampled,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.744973544973545
# Precision -  0.9562398703403565
# For  DT
# Accuracy -  0.5005291005291005
# Precision -  0.9853801169590644
# For  LR
# Accuracy -  0.7756613756613756
# Precision -  0.9852459016393442
# For  RF
# Accuracy -  0.8772486772486773
# Precision -  0.9387755102040817
# For  ETC
# Accuracy -  0.8846560846560847
# Precision -  0.9274292742927429
# c:\Users\hp\anaconda3\Lib\site-packages\xgboost\core.py:160: UserWarning: [13:43:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "class_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# For  xgb
# Accuracy -  0.8518518518518519
# Precision -  0.9547945205479452

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 1        DT  0.500529   0.985380
# 2        LR  0.775661   0.985246
# 0       SVC  0.744974   0.956240
# 5       xgb  0.851852   0.954795
# 3        RF  0.877249   0.938776
# 4       ETC  0.884656   0.927429

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0         DT   Accuracy  0.500529
# 1         LR   Accuracy  0.775661
# 2        SVC   Accuracy  0.744974
# 3        xgb   Accuracy  0.851852
# 4         RF   Accuracy  0.877249
# 5        ETC   Accuracy  0.884656
# 6         DT  Precision  0.985380
# 7         LR  Precision  0.985246
# 8        SVC  Precision  0.956240
# 9        xgb  Precision  0.954795
# 10        RF  Precision  0.938776
# 11       ETC  Precision  0.927429

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %%
# Bagging Classifier --> Best model as per precision and accuracy

# %%
rfc = RandomForestClassifier(n_estimators=50,class_weight = {0:75,1:1}, random_state=2)

rfc.fit(X_train_resampled, y_train_resampled)
y_pred = rfc.predict(X_test)
print('accuracy',accuracy_score(y_test,y_pred))
print('confusion_matrix',confusion_matrix(y_test,y_pred))
print('recall',recall_score(y_test, y_pred))
print('fi_score',f1_score(y_test, y_pred) )
print('precision',precision_score(y_test,y_pred))
confusion_matrix(y_test,y_pred)
print(classification_report(y_test,y_pred))
# Out:
# accuracy 0.8603174603174604
# confusion_matrix [[ 93  48]
#  [ 84 720]]
# recall 0.8955223880597015
# fi_score 0.916030534351145
# precision 0.9375
#               precision    recall  f1-score   support
#
#            0       0.53      0.66      0.58       141
#            1       0.94      0.90      0.92       804
#
#     accuracy                           0.86       945
#    macro avg       0.73      0.78      0.75       945
# weighted avg       0.88      0.86      0.87       945

# %%
xgb = XGBClassifier(n_estimators=50,random_state=2,class_weight = {0:11,1:1})
xgb.fit(X_train_resampled, y_train_resampled)
y_pred = xgb.predict(X_test)
print('accuracy',accuracy_score(y_test,y_pred))
print('confusion_matrix',confusion_matrix(y_test,y_pred))
print('recall',recall_score(y_test, y_pred))
print('fi_score',f1_score(y_test, y_pred) )
print('precision',precision_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy 0.8518518518518519
# confusion_matrix [[108  33]
#  [107 697]]
# recall 0.8669154228855721
# fi_score 0.9087353324641461
# precision 0.9547945205479452
#               precision    recall  f1-score   support
#
#            0       0.50      0.77      0.61       141
#            1       0.95      0.87      0.91       804
#
#     accuracy                           0.85       945
#    macro avg       0.73      0.82      0.76       945
# weighted avg       0.89      0.85      0.86       945

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Hyperparameter Tuning

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(rfc,open('model.pkl','wb'))
